# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\aruns\Downloads\iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.species.value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
sbn.countplot(x='species',data=df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
df.plot(kind='scatter',x='sepal_length',y='sepal_width')
plt.show()

# %%
sbn.set_style("whitegrid");
sbn.FacetGrid(df, hue="species", size=4) \
   .map(plt.scatter, "sepal_length", "sepal_width") \
   .add_legend();
plt.show();
# Out:
# C:\Users\aruns\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
plt.close();
sbn.set_style("whitegrid");
sbn.pairplot(data=df, hue="species", size=3);
plt.show()
# Out:
# C:\Users\aruns\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
import numpy as np
iris_setosa = df.loc[df["species"] == "setosa"];
iris_virginica = df.loc[df["species"] == "virginica"];
iris_versicolor = df.loc[df["species"] == "versicolor"];
#print(iris_setosa["petal_length"])
plt.plot(iris_setosa["petal_length"], np.zeros_like(iris_setosa['petal_length']), 'o')
plt.plot(iris_versicolor["petal_length"], np.zeros_like(iris_versicolor['petal_length']), 'o')
plt.plot(iris_virginica["petal_length"], np.zeros_like(iris_virginica['petal_length']), 'o')

plt.show()

# %%
sbn.FacetGrid(df,hue='species',size=5).map(sbn.displot,'petal_length').add_legend;
plt.show()
# Out:
# C:\Users\aruns\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\aruns\anaconda3\lib\site-packages\seaborn\distributions.py:2211: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\aruns\anaconda3\lib\site-packages\seaborn\distributions.py:2211: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\aruns\anaconda3\lib\site-packages\seaborn\distributions.py:2211: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
sbn.FacetGrid(df, hue="species", size=5) \
   .map(sbn.distplot, "petal_length") \
   .add_legend();
plt.show();
# Out:
# C:\Users\aruns\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\aruns\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\aruns\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sbn.FacetGrid(df, hue="species", size=5) \
   .map(sbn.distplot, "petal_width") \
   .add_legend();
plt.show();
# Out:
# C:\Users\aruns\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\aruns\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\aruns\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sbn.FacetGrid(df, hue="species", size=5) \
   .map(sbn.distplot, "sepal_length") \
   .add_legend();
plt.show();
# Out:
# C:\Users\aruns\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\aruns\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\aruns\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sbn.FacetGrid(df, hue="species", size=5) \
   .map(sbn.distplot, "sepal_width") \
   .add_legend();
plt.show();
# Out:
# C:\Users\aruns\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\aruns\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\aruns\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
#Median, Quantiles, Percentiles, IQR.
print("\nMedians:")
print(np.median(iris_setosa["petal_length"]))
#Median with an outlier
print(np.median(np.append(iris_setosa["petal_length"],50)));
print(np.median(iris_virginica["petal_length"]))
print(np.median(iris_versicolor["petal_length"]))


print("\nQuantiles:")
print(np.percentile(iris_setosa["petal_length"],np.arange(0, 100, 25)))
print(np.percentile(iris_virginica["petal_length"],np.arange(0, 100, 25)))
print(np.percentile(iris_versicolor["petal_length"], np.arange(0, 100, 25)))

print("\n90th Percentiles:")
print(np.percentile(iris_setosa["petal_length"],90))
print(np.percentile(iris_virginica["petal_length"],90))
print(np.percentile(iris_versicolor["petal_length"], 90))

from statsmodels import robust
print ("\nMedian Absolute Deviation")
print(robust.mad(iris_setosa["petal_length"]))
print(robust.mad(iris_virginica["petal_length"]))
print(robust.mad(iris_versicolor["petal_length"]))
# Out:
# Medians:
# 1.5
# 1.5
# 5.55
# 4.35
#
# Quantiles:
# [1.    1.4   1.5   1.575]
# [4.5   5.1   5.55  5.875]
# [3.   4.   4.35 4.6 ]
#
# 90th Percentiles:
# 1.7
# 6.31
# 4.8
#
# Median Absolute Deviation
# 0.14826022185056031
# 0.6671709983275211
# 0.5189107764769602

# %%
plt.figure(figsize=(12,7))
sbn.boxplot(x='species',y='petal_width',data=df,palette='winter')
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
plt.figure(figsize=(12,7))
sbn.boxplot(x='species',y='petal_length',data=df,palette='winter')
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
plt.figure(figsize=(12,7))
sbn.boxplot(x='species',y='sepal_length',data=df,palette='winter')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
plt.figure(figsize=(12,7))
sbn.boxplot(x='species',y='sepal_width',data=df,palette='winter')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
# violin plot
plt.figure(figsize=(12,7))
sbn.violinplot(x='species',y='petal_length',data=df,palette='winter')
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
plt.figure(figsize=(12,7))
sbn.violinplot(x='species',y='petal_width',data=df,palette='winter')
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
plt.figure(figsize=(12,7))
sbn.violinplot(x='species',y='sepal_length',data=df,palette='winter')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
plt.figure(figsize=(12,7))
sbn.violinplot(x='species',y='sepal_width',data=df,palette='winter')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
# joint plot
#2D Density plot, contors-plot
sbn.jointplot(x="petal_length", y="petal_width", data=iris_setosa, kind="kde");
plt.show();

# %%
sbn.jointplot(x="petal_length", y="sepal_width", data=iris_setosa, kind="kde");
plt.show();

# %%
sbn.jointplot(x="sepal_length", y="sepal_width", data=iris_setosa, kind="kde");
plt.show();

# %%
sbn.jointplot(x="sepal_length", y="petal_width", data=iris_setosa, kind="kde");
plt.show();

# %%
plt.figure(figsize=(12,7))
sbn.jointplot(x='sepal_length',y='sepal_width',data=df,palette='winter')

# %%
plt.figure(figsize=(12,7))
sbn.jointplot(x='sepal_length',y='petal_width',data=df,palette='winter')

# %%
plt.figure(figsize=(12,7))
sbn.swarmplot(x='sepal_length',y='petal_width',data=df)
# Out:
# C:\Users\aruns\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
sbn.swarmplot(x='species', y='petal_length', data=df)
# Out:
# C:\Users\aruns\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 14.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
plt.figure(figsize=(7,4))
sbn.heatmap(df.corr(),annot=True,cmap='summer')
# Out:
# <AxesSubplot:>

# %%
# lineplot

plt.figure(figsize=(10, 7))
sbn.lineplot(x='petal_width',y="sepal_width",data=df)
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>
